# %% [markdown]
# #CafChem tools for predicting pharmacokinetic properties using pksmart
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/MauricioCafiero/CafChem/blob/main/notebooks/PK_prediction_CafChem.ipynb)
#
# ## This notebook allows you to:
# - Generate predictions of pharmacokinetic properties using pksmart.
# - properties include:
#   * steady-state volume of distribution (VDss),
#   * total body clearance (CL),
#   * half-life (t½),
#   * fraction unbound in plasma (fu),
#   * mean residence time (MRT)
# - predicted errors for values are also produced
#
# ## Requirements:
# - This notebook will install rdkit and pksmart
# - Runs on CPU or your local runtime.

# %% [markdown]
# ## Set-up
# - install and import pksmart

# %%
# !pip install -q pksmart

# %%
import pksmart
import pandas as pd
import numpy as np
from rdkit import Chem
from rdkit.Chem import Draw, AllChem
import glob
import os

# %% [markdown]
# ## Get the pksmart help screen

# %%
# !pksmart -h
# Out:
# usage: pksmart [-h] [--smiles SMILES] [--file FILE]
#                [--log-level {DEBUG,INFO,WARNING,ERROR,CRITICAL}]
#
#  ███████████  █████   ████  █████████                                       █████
# ░░███░░░░░███░░███   ███░  ███░░░░░███                                     ░░███
#  ░███    ░███ ░███  ███   ░███    ░░░  █████████████    ██████   ████████  ███████
#  ░██████████  ░███████    ░░█████████ ░░███░░███░░███  ░░░░░███ ░░███░░███░░░███░
#  ░███░░░░░░   ░███ ░░███   ███    ░███ ░███ ░███ ░███   ███████  ░███ ░░░   ░███
#  ░███         ░███ ░░███   ███    ░███ ░███ ░███ ░███  ███░░███  ░███       ░███ ███
#  █████        █████ ░░████░░█████████  █████░███ █████░░████████ █████      ░░█████
# ░░░░░        ░░░░░   ░░░░  ░░░░░░░░░  ░░░░░ ░░░ ░░░░░  ░░░░░░░░ ░░░░░        ░░░░░
#
#
# Abstract:
# Drug exposure is a key contributor to the safety and efficacy of drugs. It can be defined using human pharmacokinetic (PK) parameters that affect the blood concentration profile of a drug, such as steady-state volume of distribution (VDss), total body clearance (CL), half-life (t½), fraction unbound in plasma (fu) and mean residence time (MRT). In this work, we used molecular structural fingerprints, physicochemical properties, and predicted animal PK data as features to model the human PK parameters VDss, CL, t½, fu and MRT for 1,283 unique compounds. First, we predicted animal PK parameters [VDss, CL, fu] for rats, dogs, and monkeys for 372 unique compounds using molecular structural fingerprints and physicochemical properties. Second, we used Morgan fingerprints, Mordred descriptors and predicted animal PK parameters in a hyperparameter-optimised Random Forest algorithm to predict human PK parameters. When validated using repeated nested cross-validation, human VDss was best predicted with an R2 of 0.55 and a Geometric Mean Fold Error (GMFE) of 2.09; CL with accuracies of R2=0.31 and GMFE=2.43, fu with R2=0.61 and GMFE=2.81, MRT with R2=0.28 and GMFE=2.49, and t½ with R2=0.31 and GMFE=2.46 for models combining Morgan fingerprints, Mordred descriptors and predicted animal PK parameters. We evaluated models with an external test set comprising 315 compounds for VDss (R2=0.33 and GMFE=2.58) and CL (R2=0.45 and GMFE=1.98). We compared our models with proprietary pharmacokinetic (PK) models from AstraZeneca and found that model predictions were similar with Pearson correlations ranging from 0.77-0.78 for human PK parameters of VDss and fu and 0.46-0.71 for animal (dog and rat) PK parameters of VDss, CL and fu. To the best of our knowledge, this is the first work that publicly releases PK models on par with industry-standard models. Early assessment and integration of predicted PK properties are crucial, such as in DMTA cycles, which is possible with models in this study based on the input of only chemical structures. We developed a webhosted application PKSmart (https://broad.io/PKSmart) which users can access using a web browser with all code also downloadable for local use.
#
# Funding
# - Cambridge Centre for Data Driven Discovery and Accelerate Programme for Scientific Discovery under the project title “Theoretical, Scientific, and Philosophical Perspectives on Biological Understanding in the Age of Artificial Intelligence”, made possible by a donation from Schmidt Futures
# - Cambridge Commonwealth, European and International Trust
# - National Institutes of Health (NIH MIRA R35 GM122547 to Anne E Carpenter)
# - Massachusetts Life Sciences Center Bits to Bytes Capital Call program for funding the data analysis (to Shantanu Singh, Broad Institute of MIT and Harvard)
# - OASIS Consortium organised by HESI (OASIS to Shantanu Singh, Broad Institute of MIT and Harvard)
# - Boak Student Support Fund (Clare Hall)
# - Jawaharlal Nehru Memorial Fund
# - Allen, Meek and Read Fund
# - Trinity Henry Barlow (Trinity College)
#
# If you use PKSmart in your work, please cite:
# PKSmart: An Open-Source Computational Model to Predict in vivo Pharmacokinetics of Small Molecules
# Srijit Seal, Maria-Anna Trapotsi, Vigneshwari Subramanian, Ola Spjuth, Nigel Greene, Andreas Bender
# bioRxiv 2024.02.02.578658; doi: https://doi.org/10.1101/2024.02.02.578658
#
# options:
#   -h, --help            show this help message and exit
#   --smiles SMILES, -s SMILES, -smi SMILES, --smi SMILES, -smiles SMILES
#                         Input SMILES string to predict properties
#   --file FILE, -f FILE  Path to file containing newline separated SMILES strings
#   --log-level {DEBUG,INFO,WARNING,ERROR,CRITICAL}, -l {DEBUG,INFO,WARNING,ERROR,CRITICAL}
#                         Set the logging level

# %% [markdown]
# ## Get PK
# - first read in a source of SMILES strings. In this example, they are saved as a list alled smiles
# - then run the loop to predict the values.
# - values are returned from the get_props function as a dataframe.
# - values for all molecules in the loop are saved to a dataframe called *out* which can be viewed in the following cell.

# %%
df = pd.read_csv('/kaggle/input/statin905/905-unique-statins.csv')
smiles = df["Ligand SMILES"].to_list()
print(len(smiles))
# Out:
# 905

# %%
def get_props(smile):
    # !pksmart -s '{smile}' 
    files = glob.glob('*.csv') 
    latest = max(files, key=os.path.getctime)
    df = pd.read_csv(latest)
    return df

# %% [markdown]
# ### This will generate a lot of output! not that it is set to read only 5 values currently

# %%
out = pd.DataFrame()

for smile in smiles[1:6]:
    try:
        smile = smile.replace("[Na+].","")
        if out.empty == True:
            out = get_props(smile)
        else:
            df = get_props(smile)
            out = pd.concat([out, df], ignore_index=True)
    except:
        print('error')
# Out:
# 2025-10-07 15:10:26.754 | INFO     | pksmart.main:main:575 - Log level set to INFO
# 2025-10-07 15:10:26.755 | INFO     | pksmart.main:predict_pk_params:410 - Starting PK parameter prediction
# 2025-10-07 15:10:26.757 | INFO     | pksmart.main:predict_pk_params:417 - Standardizing SMILES and calculating descriptors
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00,  1.92it/s]
# 2025-10-07 15:10:32.129 | INFO     | pksmart.main:predict_pk_params:431 - Predicting animal pharmacokinetic parameters
# 2025-10-07 15:10:33.630 | INFO     | pksmart.main:predict_pk_params:449 - Predicting human pharmacokinetic parameters
# 2025-10-07 15:10:34.212 | INFO     | pksmart.main:main:585 - Saving Results ...
# 2025-10-07 15:10:34.216 | INFO     | pksmart.main:main:589 - Results saved as pksmart_run_15-10-26-07-10-2025.csv
# 2025-10-07 15:10:35.840 | INFO     | pksmart.main:main:575 - Log level set to INFO
# 2025-10-07 15:10:35.842 | INFO     | pksmart.main:predict_pk_params:410 - Starting PK parameter prediction
# 2025-10-07 15:10:35.843 | INFO     | pksmart.main:predict_pk_params:417 - Standardizing SMILES and calculating descriptors
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00,  1.78it/s]
# 2025-10-07 15:10:41.274 | INFO     | pksmart.main:predict_pk_params:431 - Predicting animal pharmacokinetic parameters
# 2025-10-07 15:10:42.748 | INFO     | pksmart.main:predict_pk_params:449 - Predicting human pharmacokinetic parameters
# 2025-10-07 15:10:43.344 | INFO     | pksmart.main:main:585 - Saving Results ...
# 2025-10-07 15:10:43.347 | INFO     | pksmart.main:main:589 - Results saved as pksmart_run_15-10-35-07-10-2025.csv
# 2025-10-07 15:10:44.973 | INFO     | pksmart.main:main:575 - Log level set to INFO
# 2025-10-07 15:10:44.975 | INFO     | pksmart.main:predict_pk_params:410 - Starting PK parameter prediction
# 2025-10-07 15:10:44.976 | INFO     | pksmart.main:predict_pk_params:417 - Standardizing SMILES and calculating descriptors
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00,  2.05it/s]
# 2025-10-07 15:10:50.322 | INFO     | pksmart.main:predict_pk_params:431 - Predicting animal pharmacokinetic parameters
# 2025-10-07 15:10:51.749 | INFO     | pksmart.main:predict_pk_params:449 - Predicting human pharmacokinetic parameters
# 2025-10-07 15:10:52.287 | INFO     | pksmart.main:main:585 - Saving Results ...
# 2025-10-07 15:10:52.290 | INFO     | pksmart.main:main:589 - Results saved as pksmart_run_15-10-44-07-10-2025.csv
# 2025-10-07 15:10:53.954 | INFO     | pksmart.main:main:575 - Log level set to INFO
# 2025-10-07 15:10:53.955 | INFO     | pksmart.main:predict_pk_params:410 - Starting PK parameter prediction
# 2025-10-07 15:10:53.957 | INFO     | pksmart.main:predict_pk_params:417 - Standardizing SMILES and calculating descriptors
# [15:10:54] SMILES Parse Error: syntax error while parsing: Cannot_do
# [15:10:54] SMILES Parse Error: Failed parsing SMILES 'Cannot_do' for input: 'Cannot_do'
#   0%|                                                     | 0/1 [00:00<?, ?it/s]
# Traceback (most recent call last):
#   File "/usr/local/bin/pksmart", line 8, in <module>
#     sys.exit(main())
#              ^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pksmart/main.py", line 580, in main
#     combined_predictions = predict_pk_params(smiles)
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pksmart/main.py", line 424, in predict_pk_params
#     data_mordred = calcdesc(data)
#                    ^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pksmart/main.py", line 106, in calcdesc
#     Mordred_table = calc.pandas(Ser_Mol)
#                     ^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/mordred/_base/calculator.py", line 397, in pandas
#     return MordredDataFrame(
#            ^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pandas/core/frame.py", line 737, in __init__
#     data = list(data)
#            ^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/mordred/_base/calculator.py", line 398, in <genexpr>
#     (list(r) for r in self.map(mols, nproc, nmols, quiet, ipynb, id)),
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/mordred/_base/parallel.py", line 79, in parallel
#     for mol, (r, err) in pool.map(mols, id):
#                          ^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/mordred/_base/parallel.py", line 39, in map
#     return MolIterator(self, mols, id, self.nproc * 2 + 10)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/mordred/_base/parallel.py", line 54, in __init__
#     self.submit(mol)
#   File "/usr/local/lib/python3.11/dist-packages/mordred/_base/parallel.py", line 57, in submit
#     self.futures.append((mol, self.pool.submit(mol, self.id)))
#                               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/mordred/_base/parallel.py", line 42, in submit
#     cxt = Context.from_calculator(self.calc, mol, id)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/mordred/_base/context.py", line 63, in from_calculator
#     return cls.from_query(
#            ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/mordred/_base/context.py", line 31, in from_query
#     raise TypeError("{!r} is not rdkit.Chem.Mol instance".format(mol))
# TypeError: None is not rdkit.Chem.Mol instance
# 2025-10-07 15:10:55.754 | INFO     | pksmart.main:main:575 - Log level set to INFO
# 2025-10-07 15:10:55.755 | INFO     | pksmart.main:predict_pk_params:410 - Starting PK parameter prediction
# 2025-10-07 15:10:55.757 | INFO     | pksmart.main:predict_pk_params:417 - Standardizing SMILES and calculating descriptors
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00,  1.91it/s]
# 2025-10-07 15:11:01.183 | INFO     | pksmart.main:predict_pk_params:431 - Predicting animal pharmacokinetic parameters
# 2025-10-07 15:11:02.638 | INFO     | pksmart.main:predict_pk_params:449 - Predicting human pharmacokinetic parameters
# 2025-10-07 15:11:03.239 | INFO     | pksmart.main:main:585 - Saving Results ...
# 2025-10-07 15:11:03.242 | INFO     | pksmart.main:main:589 - Results saved as pksmart_run_15-10-55-07-10-2025.csv

# %%
out.head()
# Out:
#                                             smiles_r  VDss_L_kg  \
# 0  CC(C)n1c(CC[C@@H](O)C[C@@H](O)CC([O-])=O)c(c(c...   0.874910
# 1  CC(C)n1c(CC[C@@H](O)C[C@@H](O)CC([O-])=O)c(c(c...   1.193819
# 2  CC(C)n1c(CC[C@@H](O)C[C@@H](O)CC([O-])=O)c(c2C...   0.974609
# 3  CC(C)n1c(CC[C@@H](O)C[C@@H](O)CC([O-])=O)c(c2C...   0.974609
# 4  CC(C)n1c(CC[C@@H](O)C[C@@H](O)CC([O-])=O)c(c(c...   0.648362
#
#    Volume_of_distribution_(VDss)_folderror  \
# 0                                     2.95
# 1                                     2.95
# 2                                     2.87
# 3                                     2.87
# 4                                     2.92
#
#    Volume_of_distribution_(VDss)_lowerbound  \
# 0                                  0.296580
# 1                                  0.404684
# 2                                  0.339585
# 3                                  0.339585
# 4                                  0.222042
#
#    Volume_of_distribution_(VDss)_upperbound  CL_mL_min_kg  \
# 0                                  2.580986      3.981289
# 1                                  3.521767      4.033709
# 2                                  2.797129      3.799489
# 3                                  2.797129      3.799489
# 4                                  1.893216      2.807339
#
#    Clearance_(CL)_folderror  Clearance_(CL)_lowerbound  \
# 0                      5.43                   0.733202
# 1                      5.43                   0.742856
# 2                      4.92                   0.772254
# 3                      4.92                   0.772254
# 4                      5.25                   0.534731
#
#    Clearance_(CL)_upperbound  Fraction_unbound_in_plasma_(fup)  ...  comments  \
# 0                  21.618401                          0.045549  ...       NaN
# 1                  21.903038                          0.076920  ...       NaN
# 2                  18.693484                          0.055848  ...       NaN
# 3                  18.693484                          0.055848  ...       NaN
# 4                  14.738532                          0.067571  ...       NaN
#
#    dog_VDss_L_kg  dog_CL_mL_min_kg   dog_fup  monkey_VDss_L_kg  \
# 0       1.469133          7.256471  0.235075          0.775937
# 1       1.205301          6.746506  0.248666          0.583302
# 2       1.694422          9.776354  0.193109          1.150591
# 3       1.694422          9.776354  0.193109          1.150591
# 4       1.070188          5.015993  0.268459          0.579078
#
#    monkey_CL_mL_min_kg  monkey_fup  rat_VDss_L_kg  rat_CL_mL_min_kg   rat_fup
# 0             8.712392    0.234171       1.915010         15.143788  0.128990
# 1             7.716065    0.260240       2.143999         18.121000  0.246816
# 2            10.172208    0.239051       1.608044         23.183914  0.151055
# 3            10.172208    0.239051       1.608044         23.183914  0.151055
# 4             6.825263    0.217323       1.389224         12.878917  0.217148
#
# [5 rows x 31 columns]

# %% [markdown]
# ## View just Human, Monkey, Rat or Dog values

# %%
df_human = out[['smiles_r', 'VDss_L_kg', 'CL_mL_min_kg','Fraction_unbound_in_plasma_(fup)','MRT_hr','thalf_hr']]

df_dog = out[['smiles_r','dog_VDss_L_kg','dog_CL_mL_min_kg', 'dog_fup']]

df_monkey = out[['smiles_r','monkey_VDss_L_kg','monkey_CL_mL_min_kg', 'monkey_fup']]

df_rat = out[['smiles_r','rat_VDss_L_kg','rat_CL_mL_min_kg', 'rat_fup']]

# %%
df_human.head()
# Out:
#                                             smiles_r  VDss_L_kg  CL_mL_min_kg  \
# 0  CC(C)n1c(CC[C@@H](O)C[C@@H](O)CC([O-])=O)c(c(c...   0.874910      3.981289
# 1  CC(C)n1c(CC[C@@H](O)C[C@@H](O)CC([O-])=O)c(c(c...   1.193819      4.033709
# 2  CC(C)n1c(CC[C@@H](O)C[C@@H](O)CC([O-])=O)c(c2C...   0.974609      3.799489
# 3  CC(C)n1c(CC[C@@H](O)C[C@@H](O)CC([O-])=O)c(c2C...   0.974609      3.799489
# 4  CC(C)n1c(CC[C@@H](O)C[C@@H](O)CC([O-])=O)c(c(c...   0.648362      2.807339
#
#    Fraction_unbound_in_plasma_(fup)    MRT_hr  thalf_hr
# 0                          0.045549  4.444865  7.668279
# 1                          0.076920  5.117584  8.204483
# 2                          0.055848  5.599033  8.135067
# 3                          0.055848  5.599033  8.135067
# 4                          0.067571  3.363455  5.515214

# %%
df_rat.head()
# Out:
#                                             smiles_r  rat_VDss_L_kg  \
# 0  CC(C)n1c(CC[C@@H](O)C[C@@H](O)CC([O-])=O)c(c(c...       1.915010
# 1  CC(C)n1c(CC[C@@H](O)C[C@@H](O)CC([O-])=O)c(c(c...       2.143999
# 2  CC(C)n1c(CC[C@@H](O)C[C@@H](O)CC([O-])=O)c(c2C...       1.608044
# 3  CC(C)n1c(CC[C@@H](O)C[C@@H](O)CC([O-])=O)c(c2C...       1.608044
# 4  CC(C)n1c(CC[C@@H](O)C[C@@H](O)CC([O-])=O)c(c(c...       1.389224
#
#    rat_CL_mL_min_kg   rat_fup
# 0         15.143788  0.128990
# 1         18.121000  0.246816
# 2         23.183914  0.151055
# 3         23.183914  0.151055
# 4         12.878917  0.217148
