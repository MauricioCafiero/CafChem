# %% [markdown]
# #CafChem tools for exploring a binding site with fragments; energy evaluation with the UMA MLIP
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/MauricioCafiero/CafChem/blob/main/notebooks/FragGrow_CafChem.ipynb)
#
# ## This notebook allows you to:
# - Load a binding site and a set of chemical fragments.
# - Randomly distribute the fragments into the binding site, rejecting poses with repulsive interaction energies.
# - View all poses, view best poses. View combined poses from all fragments at once.
# - Calculate the average pose for all fragments; view them individually or all together.
#
# ## Requirements:
# - This notebook will install deepchem, Fairchem and py3Dmol
# - It will pull the CafChem tools from Github.
# - It will install all needed libraries.
# - You need to have a HF_Token set as a secret to access the UMA MLIP.

# %% [markdown]
# ## Install and set-up

# %% [markdown]
# ### Install libraries

# %%
! pip install py3Dmol
! pip install fairchem-core
# !pip install deepchem
# Out:
# Collecting py3Dmol
#   Downloading py3dmol-2.5.2-py2.py3-none-any.whl.metadata (2.1 kB)
# Downloading py3dmol-2.5.2-py2.py3-none-any.whl (7.2 kB)
# Installing collected packages: py3Dmol
# Successfully installed py3Dmol-2.5.2
# Collecting fairchem-core
#   Downloading fairchem_core-2.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting ase-db-backends>=0.10.0 (from fairchem-core)
#   Downloading ase_db_backends-0.10.0-py3-none-any.whl.metadata (600 bytes)
# Collecting ase>=3.25.0 (from fairchem-core)
#   Downloading ase-3.25.0-py3-none-any.whl.metadata (4.2 kB)
# Collecting clusterscope (from fairchem-core)
#   Downloading clusterscope-0.0.10-py3-none-any.whl.metadata (3.1 kB)
# Collecting e3nn>=0.5 (from fairchem-core)
#   Downloading e3nn-0.5.6-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: huggingface-hub>=0.27.1 in /usr/local/lib/python3.11/dist-packages (from fairchem-core) (0.34.3)
# Collecting hydra-core (from fairchem-core)
#   Downloading hydra_core-1.3.2-py3-none-any.whl.metadata (5.5 kB)
# Collecting lmdb (from fairchem-core)
#   Downloading lmdb-1.7.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.3 kB)
# Collecting numba>=0.61.2 (from fairchem-core)
#   Downloading numba-0.61.2-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.8 kB)
# Requirement already satisfied: numpy<2.3,>=2.0 in /usr/local/lib/python3.11/dist-packages (from fairchem-core) (2.0.2)
# Requirement already satisfied: orjson in /usr/local/lib/python3.11/dist-packages (from fairchem-core) (3.11.1)
# Collecting pymatgen>=2023.10.3 (from fairchem-core)
#   Downloading pymatgen-2025.6.14-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from fairchem-core) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from fairchem-core) (2.32.3)
# Collecting submitit (from fairchem-core)
#   Downloading submitit-1.5.3-py3-none-any.whl.metadata (7.9 kB)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.11/dist-packages (from fairchem-core) (2.18.0)
# Collecting torchtnt (from fairchem-core)
#   Downloading torchtnt-0.2.4-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: torch~=2.6.0 in /usr/local/lib/python3.11/dist-packages (from fairchem-core) (2.6.0+cu124)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from fairchem-core) (4.67.1)
# Requirement already satisfied: wandb in /usr/local/lib/python3.11/dist-packages (from fairchem-core) (0.21.0)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from ase>=3.25.0->fairchem-core) (1.16.1)
# Requirement already satisfied: matplotlib>=3.3.4 in /usr/local/lib/python3.11/dist-packages (from ase>=3.25.0->fairchem-core) (3.10.0)
# Collecting psycopg2-binary (from ase-db-backends>=0.10.0->fairchem-core)
#   Downloading psycopg2_binary-2.9.10-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting pymysql (from ase-db-backends>=0.10.0->fairchem-core)
#   Downloading PyMySQL-1.1.1-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: cryptography in /usr/local/lib/python3.11/dist-packages (from ase-db-backends>=0.10.0->fairchem-core) (43.0.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from e3nn>=0.5->fairchem-core) (1.13.1)
# Collecting opt_einsum_fx>=0.1.4 (from e3nn>=0.5->fairchem-core)
#   Downloading opt_einsum_fx-0.1.4-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.27.1->fairchem-core) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.27.1->fairchem-core) (2025.3.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.27.1->fairchem-core) (25.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.27.1->fairchem-core) (4.14.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.27.1->fairchem-core) (1.1.5)
# Collecting llvmlite<0.45,>=0.44.0dev0 (from numba>=0.61.2->fairchem-core)
#   Downloading llvmlite-0.44.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.8 kB)
# Collecting bibtexparser>=1.4.0 (from pymatgen>=2023.10.3->fairchem-core)
#   Downloading bibtexparser-1.4.3.tar.gz (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.6/55.6 kB 5.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: joblib>=1 in /usr/local/lib/python3.11/dist-packages (from pymatgen>=2023.10.3->fairchem-core) (1.5.1)
# Collecting monty>=2025.1.9 (from pymatgen>=2023.10.3->fairchem-core)
#   Downloading monty-2025.3.3-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: networkx>=2.7 in /usr/local/lib/python3.11/dist-packages (from pymatgen>=2023.10.3->fairchem-core) (3.5)
# Collecting palettable>=3.3.3 (from pymatgen>=2023.10.3->fairchem-core)
#   Downloading palettable-3.3.3-py2.py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: pandas>=2 in /usr/local/lib/python3.11/dist-packages (from pymatgen>=2023.10.3->fairchem-core) (2.2.2)
# Requirement already satisfied: plotly>=5.0.0 in /usr/local/lib/python3.11/dist-packages (from pymatgen>=2023.10.3->fairchem-core) (5.24.1)
# Collecting ruamel.yaml>=0.17.0 (from pymatgen>=2023.10.3->fairchem-core)
#   Downloading ruamel.yaml-0.18.14-py3-none-any.whl.metadata (24 kB)
# Collecting spglib>=2.5 (from pymatgen>=2023.10.3->fairchem-core)
#   Downloading spglib-2.6.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.2 kB)
# Requirement already satisfied: tabulate>=0.9 in /usr/local/lib/python3.11/dist-packages (from pymatgen>=2023.10.3->fairchem-core) (0.9.0)
# Collecting uncertainties>=3.1.4 (from pymatgen>=2023.10.3->fairchem-core)
#   Downloading uncertainties-3.2.3-py3-none-any.whl.metadata (7.0 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->fairchem-core) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->fairchem-core) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->fairchem-core) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->fairchem-core) (2025.7.14)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch~=2.6.0->fairchem-core) (3.1.6)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch~=2.6.0->fairchem-core)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch~=2.6.0->fairchem-core)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch~=2.6.0->fairchem-core)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch~=2.6.0->fairchem-core)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch~=2.6.0->fairchem-core)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch~=2.6.0->fairchem-core)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch~=2.6.0->fairchem-core)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch~=2.6.0->fairchem-core)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch~=2.6.0->fairchem-core)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch~=2.6.0->fairchem-core) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch~=2.6.0->fairchem-core) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch~=2.6.0->fairchem-core) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch~=2.6.0->fairchem-core)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch~=2.6.0->fairchem-core) (3.2.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->e3nn>=0.5->fairchem-core) (1.3.0)
# Requirement already satisfied: omegaconf<2.4,>=2.2 in /usr/local/lib/python3.11/dist-packages (from hydra-core->fairchem-core) (2.3.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.11/dist-packages (from hydra-core->fairchem-core) (4.9.3)
# Requirement already satisfied: cloudpickle>=1.2.1 in /usr/local/lib/python3.11/dist-packages (from submitit->fairchem-core) (3.1.1)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.11/dist-packages (from tensorboard->fairchem-core) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.11/dist-packages (from tensorboard->fairchem-core) (1.74.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard->fairchem-core) (3.8.2)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /usr/local/lib/python3.11/dist-packages (from tensorboard->fairchem-core) (5.29.5)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard->fairchem-core) (75.2.0)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.11/dist-packages (from tensorboard->fairchem-core) (1.17.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard->fairchem-core) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard->fairchem-core) (3.1.3)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from torchtnt->fairchem-core) (5.9.5)
# Collecting pyre-extensions (from torchtnt->fairchem-core)
#   Downloading pyre_extensions-0.0.32-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: click!=8.0.0,>=7.1 in /usr/local/lib/python3.11/dist-packages (from wandb->fairchem-core) (8.2.1)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb->fairchem-core) (3.1.45)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.11/dist-packages (from wandb->fairchem-core) (4.3.8)
# Requirement already satisfied: pydantic<3 in /usr/local/lib/python3.11/dist-packages (from wandb->fairchem-core) (2.11.7)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb->fairchem-core) (2.34.0)
# Requirement already satisfied: pyparsing>=2.0.3 in /usr/local/lib/python3.11/dist-packages (from bibtexparser>=1.4.0->pymatgen>=2023.10.3->fairchem-core) (3.2.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb->fairchem-core) (4.0.12)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.4->ase>=3.25.0->fairchem-core) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.4->ase>=3.25.0->fairchem-core) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.4->ase>=3.25.0->fairchem-core) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.4->ase>=3.25.0->fairchem-core) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.4->ase>=3.25.0->fairchem-core) (11.3.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.4->ase>=3.25.0->fairchem-core) (2.9.0.post0)
# Requirement already satisfied: opt-einsum in /usr/local/lib/python3.11/dist-packages (from opt_einsum_fx>=0.1.4->e3nn>=0.5->fairchem-core) (3.4.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=2->pymatgen>=2023.10.3->fairchem-core) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=2->pymatgen>=2023.10.3->fairchem-core) (2025.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly>=5.0.0->pymatgen>=2023.10.3->fairchem-core) (8.5.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3->wandb->fairchem-core) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3->wandb->fairchem-core) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3->wandb->fairchem-core) (0.4.1)
# Collecting ruamel.yaml.clib>=0.2.7 (from ruamel.yaml>=0.17.0->pymatgen>=2023.10.3->fairchem-core)
#   Downloading ruamel.yaml.clib-0.2.12-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.7 kB)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard->fairchem-core) (3.0.2)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.11/dist-packages (from cryptography->ase-db-backends>=0.10.0->fairchem-core) (1.17.1)
# Collecting typing-inspect (from pyre-extensions->torchtnt->fairchem-core)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.12->cryptography->ase-db-backends>=0.10.0->fairchem-core) (2.22)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb->fairchem-core) (5.0.2)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect->pyre-extensions->torchtnt->fairchem-core)
#   Downloading mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Downloading fairchem_core-2.3.0-py3-none-any.whl (289 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 289.8/289.8 kB 19.0 MB/s eta 0:00:00
# Downloading ase-3.25.0-py3-none-any.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 91.6 MB/s eta 0:00:00
# Downloading ase_db_backends-0.10.0-py3-none-any.whl (42 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.9/42.9 kB 3.7 MB/s eta 0:00:00
# Downloading e3nn-0.5.6-py3-none-any.whl (448 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 448.0/448.0 kB 38.1 MB/s eta 0:00:00
# Downloading numba-0.61.2-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 110.5 MB/s eta 0:00:00
# Downloading pymatgen-2025.6.14-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 106.9 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.5 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 119.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 78.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 42.5 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.6 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.4 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.0 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.1 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.8 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 76.6 MB/s eta 0:00:00
# Downloading clusterscope-0.0.10-py3-none-any.whl (10 kB)
# Downloading hydra_core-1.3.2-py3-none-any.whl (154 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 15.8 MB/s eta 0:00:00
# Downloading lmdb-1.7.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (299 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 299.6/299.6 kB 27.1 MB/s eta 0:00:00
# Downloading submitit-1.5.3-py3-none-any.whl (75 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.5/75.5 kB 6.9 MB/s eta 0:00:00
# Downloading torchtnt-0.2.4-py3-none-any.whl (163 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.5/163.5 kB 15.0 MB/s eta 0:00:00
# Downloading llvmlite-0.44.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (42.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.4/42.4 MB 14.5 MB/s eta 0:00:00
# Downloading monty-2025.3.3-py3-none-any.whl (51 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.9/51.9 kB 3.8 MB/s eta 0:00:00
# Downloading opt_einsum_fx-0.1.4-py3-none-any.whl (13 kB)
# Downloading palettable-3.3.3-py2.py3-none-any.whl (332 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 332.3/332.3 kB 28.6 MB/s eta 0:00:00
# Downloading ruamel.yaml-0.18.14-py3-none-any.whl (118 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.6/118.6 kB 11.8 MB/s eta 0:00:00
# Downloading spglib-2.6.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (809 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 809.0/809.0 kB 55.0 MB/s eta 0:00:00
# Downloading uncertainties-3.2.3-py3-none-any.whl (60 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.1/60.1 kB 5.6 MB/s eta 0:00:00
# Downloading psycopg2_binary-2.9.10-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 107.1 MB/s eta 0:00:00
# Downloading PyMySQL-1.1.1-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.0/45.0 kB 3.8 MB/s eta 0:00:00
# Downloading pyre_extensions-0.0.32-py3-none-any.whl (12 kB)
# Downloading ruamel.yaml.clib-0.2.12-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (739 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 739.1/739.1 kB 47.4 MB/s eta 0:00:00
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Building wheels for collected packages: bibtexparser
#   Building wheel for bibtexparser (setup.py) ... done
#   Created wheel for bibtexparser: filename=bibtexparser-1.4.3-py3-none-any.whl size=43549 sha256=3ee63445da67bfbcebc5a26efc10ee809dfdd07fa44d321aacefeb5bea7a6c80
#   Stored in directory: /root/.cache/pip/wheels/16/fb/76/306387739cf9d53b1c39b0c8aadbbb17dc05f256756d8fd915
# Successfully built bibtexparser
# Installing collected packages: lmdb, uncertainties, submitit, spglib, ruamel.yaml.clib, pymysql, psycopg2-binary, palettable, nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, mypy-extensions, llvmlite, clusterscope, bibtexparser, typing-inspect, ruamel.yaml, nvidia-cusparse-cu12, nvidia-cudnn-cu12, numba, hydra-core, pyre-extensions, nvidia-cusolver-cu12, monty, ase, pymatgen, ase-db-backends, torchtnt, opt_einsum_fx, e3nn, fairchem-core
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: llvmlite
#     Found existing installation: llvmlite 0.43.0
#     Uninstalling llvmlite-0.43.0:
#       Successfully uninstalled llvmlite-0.43.0
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: numba
#     Found existing installation: numba 0.60.0
#     Uninstalling numba-0.60.0:
#       Successfully uninstalled numba-0.60.0
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed ase-3.25.0 ase-db-backends-0.10.0 bibtexparser-1.4.3 clusterscope-0.0.10 e3nn-0.5.6 fairchem-core-2.3.0 hydra-core-1.3.2 llvmlite-0.44.0 lmdb-1.7.3 monty-2025.3.3 mypy-extensions-1.1.0 numba-0.61.2 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 opt_einsum_fx-0.1.4 palettable-3.3.3 psycopg2-binary-2.9.10 pymatgen-2025.6.14 pymysql-1.1.1 pyre-extensions-0.0.32 ruamel.yaml-0.18.14 ruamel.yaml.clib-0.2.12 spglib-2.6.0 submitit-1.5.3 torchtnt-0.2.4 typing-inspect-0.9.0 uncertainties-3.2.3
# Collecting deepchem
#   Downloading deepchem-2.8.0-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from deepchem) (1.5.1)
# Requirement already satisfied: numpy>=1.21 in /usr/local/lib/python3.11/dist-packages (from deepchem) (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from deepchem) (2.2.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from deepchem) (1.6.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from deepchem) (1.13.1)
# Requirement already satisfied: scipy>=1.10.1 in /usr/local/lib/python3.11/dist-packages (from deepchem) (1.16.1)
# Collecting rdkit (from deepchem)
#   Downloading rdkit-2025.3.4-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (4.1 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->deepchem) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->deepchem) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->deepchem) (2025.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from rdkit->deepchem) (11.3.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->deepchem) (3.6.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->deepchem) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->deepchem) (1.17.0)
# Downloading deepchem-2.8.0-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 48.0 MB/s eta 0:00:00
# Downloading rdkit-2025.3.4-cp311-cp311-manylinux_2_28_x86_64.whl (35.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.5/35.5 MB 55.8 MB/s eta 0:00:00
# Installing collected packages: rdkit, deepchem
# Successfully installed deepchem-2.8.0 rdkit-2025.3.4

# %% [markdown]
# ### Load CafChem from Github and import libraries

# %%
# !git clone https://github.com/MauricioCafiero/CafChem.git
# Out:
# Cloning into 'CafChem'...
# remote: Enumerating objects: 590, done.
# remote: Counting objects: 100% (167/167), done.
# remote: Compressing objects: 100% (122/122), done.
# remote: Total 590 (delta 123), reused 45 (delta 45), pack-reused 423 (from 1)
# Receiving objects: 100% (590/590), 40.13 MiB | 15.65 MiB/s, done.
# Resolving deltas: 100% (341/341), done.

# %%
import py3Dmol
import os
import torch
import numpy as np
from fairchem.core import FAIRChemCalculator, pretrained_mlip
import CafChem.CafChemFragGrow as ccfg

cpuCount = os.cpu_count()
print(cpuCount)
# Out:
# 2

# %% [markdown]
# ### Set-up Fairchem
# - Must have HF token enabled

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

predictor = pretrained_mlip.get_predict_unit("uma-s-1", device=device)
calculator = FAIRChemCalculator(predictor, task_name="omol")
model = "UMA-OMOL"

# %% [markdown]
# ## Set-up fragments and binding site
# - define the fragments and fragment cutoffs (physical size of fragments plus an optional vdW distance). This will dictate how close a fragment can be to an atom in the protein.
# - get a pre-loaded binding site, and calculate the physical dimensions. Optional parameter to enlarge or shrink the size of the active site.

# %%
frags = ccfg.define_fragments()

# %%
for frag in frags:
    cutoff = ccfg.get_fragment_cutoff(frag, 0.0)
# Out:
# OHH
# cutoff is 0.7839758934366993
# FH
# cutoff is 0.44
# CHHCHHCHH
# cutoff is 1.5668431822419242
# CHCH
# cutoff is 1.6705999999999999
# HHHCOH
# cutoff is 1.4160551209684602
# CCCCCCHHHHHH
# cutoff is 2.494682117530007

# %%
all_molecules, atom_symbols = ccfg.get_binding_site_xyz(ccfg.DRD2_data["file_location"])
# Out:
# There are 1 molecules with size: 216
# for 2, 218

# %%
max_values, min_values = ccfg.get_binding_site_dims(all_molecules, -2.5)
# Out:
# Maximum dimensions after augmentation are:
# x - Max:     17.569, Min:      5.390
# y - Max:     12.493, Min:      0.854
# z - Max:      2.368, Min:    -16.614
# Volume is 2690.583895289619 A^3

# %% [markdown]
# ## Grow Fragments
# - Loops through and adds fragments.
# - Number of attempts to add fragments is user-definable. This is a maximum, as poses are rejected based on sterics and interaction energies.
# - Find the best poses for each fragment (most attractive energies).
# - Save XYZ files for each pose for each fragment in the /frag_files folder.

# %%
new_molecules, ies = ccfg.grow_fragments(all_molecules, frags, atom_symbols, 50, calculator, ccfg.DRD2_data, max_values, min_values)
# Out:
# temp_files directory already exists
# adding fragment: water
# adding fragment: water
# adding fragment: water
# adding fragment: water
# adding fragment: water
# adding fragment: water
# adding fragment: water
# adding fragment: water
# adding fragment: water
# adding fragment: water
# adding fragment: water
# adding fragment: water
# adding fragment: water
# adding fragment: water
# Added 14 water fragments
# adding fragment: hydrogen fluoride
# adding fragment: hydrogen fluoride
# adding fragment: hydrogen fluoride
# adding fragment: hydrogen fluoride
# Added 4 hydrogen fluoride fragments
# adding fragment: cyclopropyl
# adding fragment: cyclopropyl
# adding fragment: cyclopropyl
# Added 3 cyclopropyl fragments
# adding fragment: acetylene
# adding fragment: acetylene
# adding fragment: acetylene
# adding fragment: acetylene
# adding fragment: acetylene
# adding fragment: acetylene
# Added 6 acetylene fragments
# adding fragment: methanol
# adding fragment: methanol
# adding fragment: methanol
# adding fragment: methanol
# adding fragment: methanol
# Added 5 methanol fragments
# adding fragment: phenyl
# adding fragment: phenyl
# Added 2 phenyl fragments

# %%
best_pose_for_fragments = ccfg.get_best_poses(ies, frags)
# Out:
# best pose for water is: -3.514 at location: 6
# best pose for hydrogen fluoride is: -0.929 at location: 0
# best pose for cyclopropyl is: -3.437 at location: 0
# best pose for acetylene is: -5.427 at location: 3
# best pose for methanol is: -1.219 at location: 4
# best pose for phenyl is: -2.515 at location: 0

# %%
ccfg.save_xyz_files(new_molecules, frags, ccfg.DRD2_data, atom_symbols)
# Out:
# frag_files directory already exists
# 14 files written for water.
# 4 files written for hydrogen fluoride.
# 3 files written for cyclopropyl.
# 6 files written for acetylene.
# 5 files written for methanol.
# 2 files written for phenyl.

# %% [markdown]
# ## Viewing options
# - View an individual pose for an individual fragment
# - Combine the best poses for each fragment and display all at once.
# - View all poses for a specific fragment at once (lowest energy pose in green, all others in pink).
# - Calculate and view an average pose for a specific fragment.
# - Calculate the average pose for all fragments and display them all at once.

# %%
ccfg.view_frag_pose(5, 1, frags, ccfg.DRD2_data)
# Out:
# <div id="3dmolviewer_1754050419254687"  style="position: relative; width: 800px; height: 400px;">
#         <p id="3dmolwarning_1754050419254687" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.2/build/3Dmol-min.js');
# }
#
# var viewer_1754050419254687 = null;
# var warn = document.getElementById("3dmolwarning_1754050419254687");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_1754050419254687 = $3Dmol.createViewer(document.getElementById("3dmolviewer_1754050419254687"),{backgroundColor:"white"});
# viewer_1754050419254687.zoomTo();
# 	viewer_1754050419254687.addModel("228\n\nN    3.751    11.117    -7.674\nC    4.656    9.979    -7.455\nC    5.892    10.35    -6.68\nO    6.13252135    9.79573113    -5.57614038\nC    4.97    9.236    -8.767\nC    6.026    8.173    -8.554\nO    5.829    7.343    -7.691\nO    7.058    8.277    -9.184\nH    3.509    11.328    -8.631\nN    6.407    9.745    -2.397\nC    7.599    8.946    -2.081\nC    8.692    9.727    -1.355\nO    9.358    9.217    -0.476\nC    8.153    8.248    -3.336\nS    7.066    6.892    -3.908\nH    6.328    10.104    -3.339\nH    6.775    7.38    -5.119\nN    8.892    11.012    -1.725\nC    9.788    11.949    -1.022\nC    9.338    12.156    0.413\nO    10.18659032    12.17469854    1.34204004\nC    9.951    13.323    -1.731\nC    11.022    14.201    -1.055\nO    10.386    13.15    -3.076\nH    8.319    11.394    -2.463\nH    9.685    12.712    -3.594\nN    10.52    9.361    2.555\nC    11.954    9.573    2.83\nC    12.215    10.596    3.929\nO    13.00671975    10.32244991    4.86810635\nC    12.721    9.963    1.544\nH    10.204    9.561    1.616\nN    9.072    13.058    -16.983\nC    9.828    11.798    -16.953\nC    10.733    11.603    -18.165\nO    11.80997251    10.96240378    -18.04951298\nC    8.912    10.581    -16.674\nC    9.709    9.47    -15.946\nC    8.182    10.054    -17.934\nC    8.814    8.358    -15.369\nH    8.066    13.011    -17.028\nN    15.581    14.495    -15.088\nC    14.613    13.951    -14.117\nC    15.215    12.9    -13.203\nO    15.03728584    12.97142397    -11.95926094\nC    13.325    13.414    -14.781\nC    12.396    12.739    -13.784\nC    11.696    13.506    -12.871\nC    12.282    11.347    -13.746\nC    10.884    12.899    -11.913\nC    11.474    10.735    -12.789\nC    10.774    11.511    -11.873\nH    15.352    14.409    -16.068\nN    15.551    13.828    -3.909\nC    14.458    13.095    -3.253\nC    14.877    11.839    -2.506\nO    14.08772377    11.3016143    -1.68634751\nC    13.307    12.741    -4.212\nO    12.729    13.931    -4.742\nH    15.62    13.765    -4.914\nH    12.209    14.327    -4.017\nN    13.909    0.331    -1.999\nC    14.146    1.367    -3.018\nC    15.528    1.285    -3.644\nO    15.72196405    1.73727756    -4.80218544\nC    13.875    2.794    -2.491\nC    12.395    3.104    -2.539\nC    11.61    3.219    -1.41\nC    11.529    3.307    -3.665\nC    10.284    3.549    -3.153\nC    11.722    3.24    -5.051\nN    10.3    3.464    -1.807\nC    9.174    3.776    -3.957\nC    10.613    3.447    -5.881\nC    9.345    3.718    -5.342\nH    14.113    0.564    -1.037\nH    9.484    3.416    -1.213\nN    16.114    -0.316    -7.186\nC    15.554    0.66    -8.14\nC    16.558    1.72    -8.557\nO    16.808    1.951    -9.723\nC    14.252    1.306    -7.606\nC    13.648    2.328    -8.547\nC    12.955    1.907    -9.68\nC    13.784    3.695    -8.287\nC    12.406    2.848    -10.547\nC    13.222    4.634    -9.149\nC    12.531    4.208    -10.28\nN    17.103    2.45    -7.562\nC    18.075    3.519    -7.804\nC    19.405    3.025    -8.332\nO    20.06929334    3.73713663    -9.12896069\nC    18.274    4.433    -6.585\nC    17.036    5.258    -6.3\nC    16.77    6.389    -7.067\nC    16.14    4.878    -5.307\nC    15.612    7.133    -6.855\nC    14.962    5.595    -5.116\nC    14.699    6.726    -5.885\nH    16.866    2.235    -6.605\nN    10.856    -1.209    -9.602\nC    9.852    -0.157    -9.414\nC    8.751    -0.609    -8.455\nO    8.45395134    0.10030523    -7.45889822\nC    9.257    0.337    -10.757\nC    8.432    1.619    -10.535\nO    10.287    0.654    -11.702\nH    10.913    -1.646    -10.511\nH    10.789    -0.143    -11.954\nN    7.355    0.507    -4.43\nC    5.953    0.723    -4.024\nC    5.447    -0.235    -2.951\nO    4.56059642    0.13980985    -2.14021221\nC    4.987    0.69    -5.225\nC    5.23    1.791    -6.249\nC    5.258    3.134    -5.864\nC    5.365    1.466    -7.599\nC    5.419    4.137    -6.817\nC    5.512    2.47    -8.553\nC    5.54  ...

# %%
combined_poses, combined_atoms = ccfg.combine_best_poses(frags, ccfg.DRD2_data, new_molecules, best_pose_for_fragments)

# %%
ccfg.view_combined_poses(ccfg.DRD2_data, frags)
# Out:
# <div id="3dmolviewer_1754050433112788"  style="position: relative; width: 800px; height: 400px;">
#         <p id="3dmolwarning_1754050433112788" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.2/build/3Dmol-min.js');
# }
#
# var viewer_1754050433112788 = null;
# var warn = document.getElementById("3dmolwarning_1754050433112788");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_1754050433112788 = $3Dmol.createViewer(document.getElementById("3dmolviewer_1754050433112788"),{backgroundColor:"white"});
# viewer_1754050433112788.zoomTo();
# 	viewer_1754050433112788.addModel("252\n\nN    3.75100000    11.11700000    -7.67400000\nC    4.65600000    9.97900000    -7.45500000\nC    5.89200000    10.35000000    -6.68000000\nO    6.13252135    9.79573113    -5.57614038\nC    4.97000000    9.23600000    -8.76700000\nC    6.02600000    8.17300000    -8.55400000\nO    5.82900000    7.34300000    -7.69100000\nO    7.05800000    8.27700000    -9.18400000\nH    3.50900000    11.32800000    -8.63100000\nN    6.40700000    9.74500000    -2.39700000\nC    7.59900000    8.94600000    -2.08100000\nC    8.69200000    9.72700000    -1.35500000\nO    9.35800000    9.21700000    -0.47600000\nC    8.15300000    8.24800000    -3.33600000\nS    7.06600000    6.89200000    -3.90800000\nH    6.32800000    10.10400000    -3.33900000\nH    6.77500000    7.38000000    -5.11900000\nN    8.89200000    11.01200000    -1.72500000\nC    9.78800000    11.94900000    -1.02200000\nC    9.33800000    12.15600000    0.41300000\nO    10.18659032    12.17469854    1.34204004\nC    9.95100000    13.32300000    -1.73100000\nC    11.02200000    14.20100000    -1.05500000\nO    10.38600000    13.15000000    -3.07600000\nH    8.31900000    11.39400000    -2.46300000\nH    9.68500000    12.71200000    -3.59400000\nN    10.52000000    9.36100000    2.55500000\nC    11.95400000    9.57300000    2.83000000\nC    12.21500000    10.59600000    3.92900000\nO    13.00671975    10.32244991    4.86810635\nC    12.72100000    9.96300000    1.54400000\nH    10.20400000    9.56100000    1.61600000\nN    9.07200000    13.05800000    -16.98300000\nC    9.82800000    11.79800000    -16.95300000\nC    10.73300000    11.60300000    -18.16500000\nO    11.80997251    10.96240378    -18.04951298\nC    8.91200000    10.58100000    -16.67400000\nC    9.70900000    9.47000000    -15.94600000\nC    8.18200000    10.05400000    -17.93400000\nC    8.81400000    8.35800000    -15.36900000\nH    8.06600000    13.01100000    -17.02800000\nN    15.58100000    14.49500000    -15.08800000\nC    14.61300000    13.95100000    -14.11700000\nC    15.21500000    12.90000000    -13.20300000\nO    15.03728584    12.97142397    -11.95926094\nC    13.32500000    13.41400000    -14.78100000\nC    12.39600000    12.73900000    -13.78400000\nC    11.69600000    13.50600000    -12.87100000\nC    12.28200000    11.34700000    -13.74600000\nC    10.88400000    12.89900000    -11.91300000\nC    11.47400000    10.73500000    -12.78900000\nC    10.77400000    11.51100000    -11.87300000\nH    15.35200000    14.40900000    -16.06800000\nN    15.55100000    13.82800000    -3.90900000\nC    14.45800000    13.09500000    -3.25300000\nC    14.87700000    11.83900000    -2.50600000\nO    14.08772377    11.30161430    -1.68634751\nC    13.30700000    12.74100000    -4.21200000\nO    12.72900000    13.93100000    -4.74200000\nH    15.62000000    13.76500000    -4.91400000\nH    12.20900000    14.32700000    -4.01700000\nN    13.90900000    0.33100000    -1.99900000\nC    14.14600000    1.36700000    -3.01800000\nC    15.52800000    1.28500000    -3.64400000\nO    15.72196405    1.73727756    -4.80218544\nC    13.87500000    2.79400000    -2.49100000\nC    12.39500000    3.10400000    -2.53900000\nC    11.61000000    3.21900000    -1.41000000\nC    11.52900000    3.30700000    -3.66500000\nC    10.28400000    3.54900000    -3.15300000\nC    11.72200000    3.24000000    -5.05100000\nN    10.30000000    3.46400000    -1.80700000\nC    9.17400000    3.77600000    -3.95700000\nC    10.61300000    3.44700000    -5.88100000\nC    9.34500000    3.71800000    -5.34200000\nH    14.11300000    0.56400000    -1.03700000\nH    9.48400000    3.41600000    -1.21300000\nN    16.11400000    -0.31600000    -7.18600000\nC    15.55400000    0.66000000    -8.14000000\nC    16.55800000    1.72000000    -8.55700000\nO    16.80800000    1.95100000    -9.72300000\nC    14.25200000    1.30600000    -7.60600000\nC    13.64800000    2.32800000    -8.54700000\nC    12.95500000    1.90700000     ...

# %%
ccfg.view_all_poses_for_frag(5, frags, ccfg.DRD2_data, new_molecules, best_pose_for_fragments)
# Out:
# <div id="3dmolviewer_17540544027570918"  style="position: relative; width: 800px; height: 400px;">
#         <p id="3dmolwarning_17540544027570918" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.2/build/3Dmol-min.js');
# }
#
# var viewer_17540544027570918 = null;
# var warn = document.getElementById("3dmolwarning_17540544027570918");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17540544027570918 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17540544027570918"),{backgroundColor:"white"});
# viewer_17540544027570918.zoomTo();
# 	viewer_17540544027570918.addModel("240\n\nN    3.75100000    11.11700000    -7.67400000\nC    4.65600000    9.97900000    -7.45500000\nC    5.89200000    10.35000000    -6.68000000\nO    6.13252135    9.79573113    -5.57614038\nC    4.97000000    9.23600000    -8.76700000\nC    6.02600000    8.17300000    -8.55400000\nO    5.82900000    7.34300000    -7.69100000\nO    7.05800000    8.27700000    -9.18400000\nH    3.50900000    11.32800000    -8.63100000\nN    6.40700000    9.74500000    -2.39700000\nC    7.59900000    8.94600000    -2.08100000\nC    8.69200000    9.72700000    -1.35500000\nO    9.35800000    9.21700000    -0.47600000\nC    8.15300000    8.24800000    -3.33600000\nS    7.06600000    6.89200000    -3.90800000\nH    6.32800000    10.10400000    -3.33900000\nH    6.77500000    7.38000000    -5.11900000\nN    8.89200000    11.01200000    -1.72500000\nC    9.78800000    11.94900000    -1.02200000\nC    9.33800000    12.15600000    0.41300000\nO    10.18659032    12.17469854    1.34204004\nC    9.95100000    13.32300000    -1.73100000\nC    11.02200000    14.20100000    -1.05500000\nO    10.38600000    13.15000000    -3.07600000\nH    8.31900000    11.39400000    -2.46300000\nH    9.68500000    12.71200000    -3.59400000\nN    10.52000000    9.36100000    2.55500000\nC    11.95400000    9.57300000    2.83000000\nC    12.21500000    10.59600000    3.92900000\nO    13.00671975    10.32244991    4.86810635\nC    12.72100000    9.96300000    1.54400000\nH    10.20400000    9.56100000    1.61600000\nN    9.07200000    13.05800000    -16.98300000\nC    9.82800000    11.79800000    -16.95300000\nC    10.73300000    11.60300000    -18.16500000\nO    11.80997251    10.96240378    -18.04951298\nC    8.91200000    10.58100000    -16.67400000\nC    9.70900000    9.47000000    -15.94600000\nC    8.18200000    10.05400000    -17.93400000\nC    8.81400000    8.35800000    -15.36900000\nH    8.06600000    13.01100000    -17.02800000\nN    15.58100000    14.49500000    -15.08800000\nC    14.61300000    13.95100000    -14.11700000\nC    15.21500000    12.90000000    -13.20300000\nO    15.03728584    12.97142397    -11.95926094\nC    13.32500000    13.41400000    -14.78100000\nC    12.39600000    12.73900000    -13.78400000\nC    11.69600000    13.50600000    -12.87100000\nC    12.28200000    11.34700000    -13.74600000\nC    10.88400000    12.89900000    -11.91300000\nC    11.47400000    10.73500000    -12.78900000\nC    10.77400000    11.51100000    -11.87300000\nH    15.35200000    14.40900000    -16.06800000\nN    15.55100000    13.82800000    -3.90900000\nC    14.45800000    13.09500000    -3.25300000\nC    14.87700000    11.83900000    -2.50600000\nO    14.08772377    11.30161430    -1.68634751\nC    13.30700000    12.74100000    -4.21200000\nO    12.72900000    13.93100000    -4.74200000\nH    15.62000000    13.76500000    -4.91400000\nH    12.20900000    14.32700000    -4.01700000\nN    13.90900000    0.33100000    -1.99900000\nC    14.14600000    1.36700000    -3.01800000\nC    15.52800000    1.28500000    -3.64400000\nO    15.72196405    1.73727756    -4.80218544\nC    13.87500000    2.79400000    -2.49100000\nC    12.39500000    3.10400000    -2.53900000\nC    11.61000000    3.21900000    -1.41000000\nC    11.52900000    3.30700000    -3.66500000\nC    10.28400000    3.54900000    -3.15300000\nC    11.72200000    3.24000000    -5.05100000\nN    10.30000000    3.46400000    -1.80700000\nC    9.17400000    3.77600000    -3.95700000\nC    10.61300000    3.44700000    -5.88100000\nC    9.34500000    3.71800000    -5.34200000\nH    14.11300000    0.56400000    -1.03700000\nH    9.48400000    3.41600000    -1.21300000\nN    16.11400000    -0.31600000    -7.18600000\nC    15.55400000    0.66000000    -8.14000000\nC    16.55800000    1.72000000    -8.55700000\nO    16.80800000    1.95100000    -9.72300000\nC    14.25200000    1.30600000    -7.60600000\nC    13.64800000    2.32800000    -8.54700000\nC    12.95500000    1.90700000    ...

# %%
average_coords = ccfg.average_pose_for_frag(5, frags, ccfg.DRD2_data, new_molecules, atom_symbols, display_flag = True)
# Out:
# <div id="3dmolviewer_1754054427035488"  style="position: relative; width: 800px; height: 400px;">
#         <p id="3dmolwarning_1754054427035488" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.2/build/3Dmol-min.js');
# }
#
# var viewer_1754054427035488 = null;
# var warn = document.getElementById("3dmolwarning_1754054427035488");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_1754054427035488 = $3Dmol.createViewer(document.getElementById("3dmolviewer_1754054427035488"),{backgroundColor:"white"});
# viewer_1754054427035488.zoomTo();
# 	viewer_1754054427035488.addModel("228\n\nN    3.751    11.117    -7.674\nC    4.656    9.979    -7.455\nC    5.892    10.35    -6.68\nO    6.13252135    9.79573113    -5.57614038\nC    4.97    9.236    -8.767\nC    6.026    8.173    -8.554\nO    5.829    7.343    -7.691\nO    7.058    8.277    -9.184\nH    3.509    11.328    -8.631\nN    6.407    9.745    -2.397\nC    7.599    8.946    -2.081\nC    8.692    9.727    -1.355\nO    9.358    9.217    -0.476\nC    8.153    8.248    -3.336\nS    7.066    6.892    -3.908\nH    6.328    10.104    -3.339\nH    6.775    7.38    -5.119\nN    8.892    11.012    -1.725\nC    9.788    11.949    -1.022\nC    9.338    12.156    0.413\nO    10.18659032    12.17469854    1.34204004\nC    9.951    13.323    -1.731\nC    11.022    14.201    -1.055\nO    10.386    13.15    -3.076\nH    8.319    11.394    -2.463\nH    9.685    12.712    -3.594\nN    10.52    9.361    2.555\nC    11.954    9.573    2.83\nC    12.215    10.596    3.929\nO    13.00671975    10.32244991    4.86810635\nC    12.721    9.963    1.544\nH    10.204    9.561    1.616\nN    9.072    13.058    -16.983\nC    9.828    11.798    -16.953\nC    10.733    11.603    -18.165\nO    11.80997251    10.96240378    -18.04951298\nC    8.912    10.581    -16.674\nC    9.709    9.47    -15.946\nC    8.182    10.054    -17.934\nC    8.814    8.358    -15.369\nH    8.066    13.011    -17.028\nN    15.581    14.495    -15.088\nC    14.613    13.951    -14.117\nC    15.215    12.9    -13.203\nO    15.03728584    12.97142397    -11.95926094\nC    13.325    13.414    -14.781\nC    12.396    12.739    -13.784\nC    11.696    13.506    -12.871\nC    12.282    11.347    -13.746\nC    10.884    12.899    -11.913\nC    11.474    10.735    -12.789\nC    10.774    11.511    -11.873\nH    15.352    14.409    -16.068\nN    15.551    13.828    -3.909\nC    14.458    13.095    -3.253\nC    14.877    11.839    -2.506\nO    14.08772377    11.3016143    -1.68634751\nC    13.307    12.741    -4.212\nO    12.729    13.931    -4.742\nH    15.62    13.765    -4.914\nH    12.209    14.327    -4.017\nN    13.909    0.331    -1.999\nC    14.146    1.367    -3.018\nC    15.528    1.285    -3.644\nO    15.72196405    1.73727756    -4.80218544\nC    13.875    2.794    -2.491\nC    12.395    3.104    -2.539\nC    11.61    3.219    -1.41\nC    11.529    3.307    -3.665\nC    10.284    3.549    -3.153\nC    11.722    3.24    -5.051\nN    10.3    3.464    -1.807\nC    9.174    3.776    -3.957\nC    10.613    3.447    -5.881\nC    9.345    3.718    -5.342\nH    14.113    0.564    -1.037\nH    9.484    3.416    -1.213\nN    16.114    -0.316    -7.186\nC    15.554    0.66    -8.14\nC    16.558    1.72    -8.557\nO    16.808    1.951    -9.723\nC    14.252    1.306    -7.606\nC    13.648    2.328    -8.547\nC    12.955    1.907    -9.68\nC    13.784    3.695    -8.287\nC    12.406    2.848    -10.547\nC    13.222    4.634    -9.149\nC    12.531    4.208    -10.28\nN    17.103    2.45    -7.562\nC    18.075    3.519    -7.804\nC    19.405    3.025    -8.332\nO    20.06929334    3.73713663    -9.12896069\nC    18.274    4.433    -6.585\nC    17.036    5.258    -6.3\nC    16.77    6.389    -7.067\nC    16.14    4.878    -5.307\nC    15.612    7.133    -6.855\nC    14.962    5.595    -5.116\nC    14.699    6.726    -5.885\nH    16.866    2.235    -6.605\nN    10.856    -1.209    -9.602\nC    9.852    -0.157    -9.414\nC    8.751    -0.609    -8.455\nO    8.45395134    0.10030523    -7.45889822\nC    9.257    0.337    -10.757\nC    8.432    1.619    -10.535\nO    10.287    0.654    -11.702\nH    10.913    -1.646    -10.511\nH    10.789    -0.143    -11.954\nN    7.355    0.507    -4.43\nC    5.953    0.723    -4.024\nC    5.447    -0.235    -2.951\nO    4.56059642    0.13980985    -2.14021221\nC    4.987    0.69    -5.225\nC    5.23    1.791    -6.249\nC    5.258    3.134    -5.864\nC    5.365    1.466    -7.599\nC    5.419    4.137    -6.817\nC    5.512    2.47    -8.553\nC    5.54  ...

# %%
average_poses, averagae_atoms = ccfg.combine_average_poses(frags, ccfg.DRD2_data, new_molecules, atom_symbols)
# Out:
# <div id="3dmolviewer_1754054439225288"  style="position: relative; width: 800px; height: 400px;">
#         <p id="3dmolwarning_1754054439225288" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.2/build/3Dmol-min.js');
# }
#
# var viewer_1754054439225288 = null;
# var warn = document.getElementById("3dmolwarning_1754054439225288");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_1754054439225288 = $3Dmol.createViewer(document.getElementById("3dmolviewer_1754054439225288"),{backgroundColor:"white"});
# viewer_1754054439225288.zoomTo();
# 	viewer_1754054439225288.addModel("36\n\nO    12.3275801648859    7.029638601968837    -7.818310365197601\nH    12.346363863630875    7.076239056057844    -6.859626073921189\nH    13.13654147252886    6.621276683603339    -8.135204919781497\nF    11.169161005870151    8.44147021673187    -7.099603583079404\nH    10.8536858389459    8.20718769931957    -7.886996192321498\nC    12.315855730727398    7.633269407253209    -11.304083279285512\nH    11.44619009829201    7.694345982318103    -11.967576496574958\nH    13.183022059591988    7.1339939524806155    -11.750038600405386\nC    12.0703805879364    7.452042086058751    -9.830996802794257\nH    12.769417914480192    6.827432770656355    -9.26392249530091\nH    11.033002206640422    7.3881905962292    -9.484845375942829\nC    12.563557599026009    8.773119150294052    -10.35423966944908\nH    13.601629294265493    9.054963351118024    -10.146175742547946\nH    11.866115771202834    9.617872471874433    -10.36731804666429\nC    11.763960568263236    7.7062046526586405    -7.627416766921339\nH    11.795358377761678    8.215974975719819    -6.687178289042029\nC    11.728712859132838    7.1339279124146335    -8.682944299284543\nH    11.697315049634396    6.624157589353456    -9.623182777163853\nH    12.319373473934206    5.9065807039173315    -11.580227027725364\nH    12.508453932885555    7.659450398458922    -11.868823368777043\nH    13.939157011909645    6.67677150204194    -11.44566325293826\nC    12.856261732607015    6.819287073860538    -11.246609417179439\nO    12.587805998986322    7.150885989089479    -9.912982290522153\nH    12.884004487019562    6.427330287084473    -9.346584237584235\nC    10.510248973380408    9.679212439723512    -5.627255437448765\nC    10.197778766999434    9.934504490605407    -6.962792694316108\nC    10.412802520442003    8.95243776283079    -7.929504371652493\nC    10.941645545284596    7.714795949792116    -7.56101510167075\nC    11.254459750226832    7.459804371159076    -6.2258508480440335\nC    11.038389092433878    8.441929335956656    -5.2588172860539295\nH    10.340228992612499    10.453465287883354    -4.865173708022024\nH    9.780698688675379    10.90978328616282    -7.252822461166475\nH    10.165948404512529    9.153366468404242    -8.982114086352702\nH    11.111151653775954    6.94064694081301    -8.323417440997424\nH    11.671271233899597    6.484499799319273    -5.935121755449421\nH    11.284887147514022    8.240614125409042    -4.206277539750316\n","xyz");
# 	viewer_1754054439225288.setStyle({"stick": {}, "sphere": {"radius": 0.5}});
# 	viewer_1754054439225288.zoomTo();
# viewer_1754054439225288.render();
# });
# </script>
